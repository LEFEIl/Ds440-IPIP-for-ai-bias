# %%
import pathlib
import warnings

import numpy as np
import pandas as pd

import seaborn as sns
import geopandas as gpd
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

sns.set_style("white")
warnings.filterwarnings("ignore")

pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %%
df = pd.read_csv("/kaggle/input/pip-neo-big-five-personality-120-item-version/IPIP120-SCORES.csv")

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df["age"], bins=30, kde=True)
plt.title("Age Distribution - IPIP120")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
print("O:", df["openness"].mean())
print("C:", df["conscientiousness"].mean())
print("E:", df["extraversion"].mean())
print("A:", df["agreeableness"].mean())
print("N:", df["neuroticism"].mean())
# Out:
# O: 40.41213566412523
# C: 55.37511544517535
# E: 52.901934580605506
# A: 51.644964872478134
# N: 45.034001655051085

# %%
df_matrix_domain = df[
    ["openness", "conscientiousness", "extraversion", "agreeableness", "neuroticism"]
]

# %%
df_matrix_domain.corr()
# Out:
#                    openness  conscientiousness  extraversion  agreeableness  \
# openness           1.000000          -0.098511      0.141352       0.172483
# conscientiousness -0.098511           1.000000      0.234794       0.303368
# extraversion       0.141352           0.234794      1.000000       0.106138
# agreeableness      0.172483           0.303368      0.106138       1.000000
# neuroticism       -0.049918          -0.447574     -0.506848      -0.272791
#
#                    neuroticism
# openness             -0.049918
# conscientiousness    -0.447574
# extraversion         -0.506848
# agreeableness        -0.272791
# neuroticism           1.000000

# %%
sns.heatmap(df_matrix_domain.corr(), annot=True)
plt.show()

# %% [markdown]
# ## Openness Distribuition (O)

# %%
df_O = df[
    [
        "facet_imagination",
        "facet_artistic_interests",
        "facet_emotionality",
        "facet_adventurousness",
        "facet_intellect",
        "facet_liberalism",
    ]
]

plt.figure(figsize=(12, 8))
for column in df_O.columns:
    sns.kdeplot(df_O[column], label=column, shade=False)

plt.xlabel("Values")
plt.ylabel("Density")
plt.title("Data Distribution Openness")
plt.legend()
plt.show()

data = []
for column in df_O.columns:
    mean_value = df_O[column].mean()
    std_dev = df_O[column].std()
    data.append({
        "Facet": column,
        "Mean": mean_value,
        "Standard Deviation": std_dev
    })

df_stats = pd.DataFrame(data)

# %%
df_stats
# Out:
#                       Facet       Mean  Standard Deviation
# 0         facet_imagination  41.713636           28.940016
# 1  facet_artistic_interests  43.752140           28.782212
# 2        facet_emotionality  47.044041           27.797027
# 3     facet_adventurousness  46.246548           28.329326
# 4           facet_intellect  44.188520           29.015410
# 5          facet_liberalism  46.830359           28.863746

# %% [markdown]
# ## Conscientiousness Distribuition (C)

# %%
df_C = df[
    [
        "facet_self_efficacy",
        "facet_orderliness",
        "facet_dutifulness",
        "facet_achievement_striving",
        "facet_self_discipline",
        "facet_cautiousness",
    ]
]

plt.figure(figsize=(12, 8))
for column in df_C.columns:
    sns.kdeplot(df_C[column], label=column, shade=False)

plt.xlabel("Values")
plt.ylabel("Density")
plt.title("Data Distribution Conscientiousness")
plt.legend()
plt.show()

data = []
for column in df_C.columns:
    mean_value = df_C[column].mean()
    std_dev = df_C[column].std()
    data.append({
        "Facet": column,
        "Mean": mean_value,
        "Standard Deviation": std_dev
    })

df_stats = pd.DataFrame(data)

# %%
df_stats
# Out:
#                         Facet       Mean  Standard Deviation
# 0         facet_self_efficacy  54.932992           28.173689
# 1           facet_orderliness  54.873113           29.972011
# 2           facet_dutifulness  52.493024           27.693217
# 3  facet_achievement_striving  53.323192           28.269067
# 4       facet_self_discipline  55.196467           28.619392
# 5          facet_cautiousness  54.347658           29.980202

# %% [markdown]
# ## Extraversion Distribuition (E)

# %%
df_E = df[
    [
        "facet_friendliness",
        "facet_gregariousness",
        "facet_assertiveness",
        "facet_activity_level",
        "facet_excitement_seeking",
        "facet_cheerfulness",
    ]
]

plt.figure(figsize=(12, 8))
for column in df_E.columns:
    sns.kdeplot(df_E[column], label=column, shade=False)

plt.xlabel("Values")
plt.ylabel("Density")
plt.title("Data Distribution Extraversion")
plt.legend()
plt.show()

data = []
for column in df_E.columns:
    mean_value = df_E[column].mean()
    std_dev = df_E[column].std()
    data.append({
        "Facet": column,
        "Mean": mean_value,
        "Standard Deviation": std_dev
    })

df_stats = pd.DataFrame(data)

# %%
df_stats
# Out:
#                       Facet       Mean  Standard Deviation
# 0        facet_friendliness  55.260634           28.633697
# 1      facet_gregariousness  53.540235           29.495008
# 2       facet_assertiveness  51.081214           28.003128
# 3      facet_activity_level  51.923806           28.513873
# 4  facet_excitement_seeking  45.064940           27.838316
# 5        facet_cheerfulness  55.888762           27.443881

# %% [markdown]
# ## Agreeableness Distribuition (A)

# %%
df_A = df[
    [
        "facet_trust",
        "facet_morality",
        "facet_altruism",
        "facet_cooperation",
        "facet_modesty",
        "facet_sympathy",
    ]
]

plt.figure(figsize=(12, 8))
for column in df_A.columns:
    sns.kdeplot(df_A[column], label=column, shade=False)

plt.xlabel("Values")
plt.ylabel("Density")
plt.title("Data Distribution Agreeableness")
plt.legend()
plt.show()

data = []
for column in df_A.columns:
    mean_value = df_A[column].mean()
    std_dev = df_A[column].std()
    data.append({
        "Facet": column,
        "Mean": mean_value,
        "Standard Deviation": std_dev
    })

df_stats = pd.DataFrame(data)

# %%
df_stats
# Out:
#                Facet       Mean  Standard Deviation
# 0        facet_trust  53.327893           28.340929
# 1     facet_morality  50.688821           28.059705
# 2     facet_altruism  54.828488           26.779812
# 3  facet_cooperation  52.208811           27.776260
# 4      facet_modesty  49.037872           27.513337
# 5     facet_sympathy  51.613677           28.318696

# %% [markdown]
# ## Neuroticism Distribuition (N)

# %%
df_N = df[
    [
        "facet_anxiety",
        "facet_anger",
        "facet_depression",
        "facet_self_consciousness",
        "facet_immoderation",
        "facet_vulnerability",
    ]
]

plt.figure(figsize=(12, 8))
for column in df_N.columns:
    sns.kdeplot(df_N[column], label=column, shade=False)

plt.xlabel("Values")
plt.ylabel("Density")
plt.title("Data Distribution Neuroticism")
plt.legend()
plt.show()

data = []
for column in df_N.columns:
    mean_value = df_N[column].mean()
    std_dev = df_N[column].std()
    data.append({
        "Facet": column,
        "Mean": mean_value,
        "Standard Deviation": std_dev
    })

df_stats = pd.DataFrame(data)

# %%
df_stats
# Out:
#                       Facet       Mean  Standard Deviation
# 0             facet_anxiety  48.524562           29.146029
# 1               facet_anger  45.279672           29.518447
# 2          facet_depression  41.414211           28.401918
# 3  facet_self_consciousness  47.068191           28.464582
# 4        facet_immoderation  47.197800           28.474458
# 5       facet_vulnerability  49.772090           28.890719

# %% [markdown]
# ## Facets

# %%
df_matrix_facets = df[
    [
        "facet_imagination",
        "facet_artistic_interests",
        "facet_emotionality",
        "facet_adventurousness",
        "facet_intellect",
        "facet_liberalism",
        "facet_self_efficacy",
        "facet_orderliness",
        "facet_dutifulness",
        "facet_achievement_striving",
        "facet_self_discipline",
        "facet_cautiousness",
        "facet_friendliness",
        "facet_gregariousness",
        "facet_assertiveness",
        "facet_activity_level",
        "facet_excitement_seeking",
        "facet_cheerfulness",
        "facet_trust",
        "facet_morality",
        "facet_altruism",
        "facet_cooperation",
        "facet_modesty",
        "facet_sympathy",
        "facet_anxiety",
        "facet_anger",
        "facet_depression",
        "facet_self_consciousness",
        "facet_immoderation",
        "facet_vulnerability",
    ]
]

# %%
df_matrix_facets.corr()
# Out:
#                             facet_imagination  facet_artistic_interests  \
# facet_imagination                    1.000000                  0.358069
# facet_artistic_interests             0.358069                  1.000000
# facet_emotionality                   0.229405                  0.300230
# facet_adventurousness                0.166887                  0.275381
# facet_intellect                      0.315240                  0.508333
# facet_liberalism                     0.164615                  0.213274
# facet_self_efficacy                 -0.112429                  0.051702
# facet_orderliness                   -0.260323                 -0.032536
# facet_dutifulness                   -0.207237                  0.015612
# facet_achievement_striving          -0.146134                  0.072200
# facet_self_discipline               -0.245610                  0.004675
# facet_cautiousness                  -0.251124                  0.034904
# facet_friendliness                  -0.085551                  0.040260
# facet_gregariousness                -0.043568                  0.026728
# facet_assertiveness                 -0.037680                  0.062403
# facet_activity_level                -0.120114                  0.029652
# facet_excitement_seeking             0.306732                  0.101355
# facet_cheerfulness                   0.005324                  0.102904
# facet_trust                         -0.031716                  0.046417
# facet_morality                      -0.096149                  0.131178
# facet_altruism                       0.071136                  0.248464
# facet_cooperation                   -0.124615                  0.118275
# facet_modesty                       -0.039667                 -0.001313
# facet_sympathy                       0.107249                  0.277265
# facet_anxiety                        0.121094                 -0.060234
# facet_anger                          0.105669                 -0.109452
# facet_depression                     0.192889                  0.026902
# facet_self_consciousness             0.052260                 -0.076235
# facet_immoderation                   0.204437                 -0.002240
# facet_vulnerability                  0.107693                 -0.069258
#
#                             facet_emotionality  facet_adventurousness  \
# facet_imagination                     0.229405               0.166887
# facet_artistic_interests              0.300230               0.275381
# facet_emotionality                    1.000000               0.077864
# facet_adventurousness                 0.077864               1.000000
# facet_intellect                       0.206991               0.325610
# facet_liberalism                      0.083392               0.225122
# facet_self_efficacy                   0.032654               0.102725
# facet_orderliness                    -0.004249              -0.085052
# facet_dutifulness                     0.081860              -0.064307
# facet_achievement_striving            0.076506               0.087044
# facet_self_discipline                 0.004545               0.075984
# facet_cautiousness                   -0.023483              -0.060523
# facet_friendliness                    0.126293               0.267482
# facet_gregariousness                  0.073769               0.295630
# facet_assertiveness                   0.062401               0.216017
# facet_activity_level                  0.030101               0.137293
# facet_excitement_seeking              0.054933               0.334492
# facet_cheerfulness                    0.085801               0.226369
# facet_trust                           0.101505               0.096045
# facet_morality                        0.143609               0.074561
# facet_altruism                        0.481985               0.125779
# facet_cooperation                     0.075309               0.053595
# facet_modesty                         0.058612              -0.067652
# facet_sympathy                        0.356530               0.129477
# facet_anxiety                         0.180802              -0.359954
# facet_anger                           0.062218              -0.185652
# facet_depression                      0.114508              -0.189165
# facet_self_consciousness             -0.037295              -0.356023
# facet_immoderation                    0.081290              -0.000214
# facet_vulnerability                   0.141560              -0.334549
#
#                             facet_intellect  facet_liberalism  \
# facet_imagination                  0.315240          0.164615
# facet_artistic_interests           0.508333          0.213274
# facet_emotionality                 0.206991          0.083392
# facet_adventurousness              0.325610          0.225122
# facet_intellect                    1.000000          0.213843
# facet_liberalism                   0.213843          1.000000
# facet_self_efficacy                0.143514         -0.120353
# facet_orderliness                 -0.087098         -0.134038
# facet_dutifulness                  0.020532         -0.188993
# facet_achievement_striving         0.117019         -0.131252
# facet_self_discipline              0.034156         -0.153561
# facet_cautiousness                 0.110769         -0.078810
# facet_friendliness                -0.004317         -0.061580
# facet_gregariousness              -0.034448         -0.012370
# facet_assertiveness                0.156144         -0.074365
# facet_activity_level               0.031286         -0.093247
# facet_excitement_seeking           0.046534          0.080856
# facet_cheerfulness                 0.010926         -0.066196
# facet_trust                        0.002914          0.010266
# facet_morality                     0.110021         -0.085458
# facet_altruism                     0.160199         -0.004454
# facet_cooperation                  0.071284          0.000349
# facet_modesty                     -0.111258         -0.027403
# facet_sympathy                     0.192713          0.128739
# facet_anxiety                     -0.141704          0.017029
# facet_anger                       -0.102461         -0.034210
# facet_depression                   0.001567          0.095894
# facet_self_consciousness          -0.099355          0.017717
# facet_immoderation                -0.023154          0.112502
# facet_vulnerability               -0.181511          0.043565
#
#                             facet_self_efficacy  facet_orderliness  \
# facet_imagination                     -0.112429          -0.260323
# facet_artistic_interests               0.051702          -0.032536
# facet_emotionality                     0.032654          -0.004249
# facet_adventurousness                  0.102725          -0.085052
# facet_intellect                        0.143514          -0.087098
# facet_liberalism                      -0.120353          -0.134038
# facet_self_efficacy                    1.000000           0.306921
# facet_orderliness                      0.306921           1.000000
# facet_dutifulness                      0.373003           0.311126
# facet_achievement_striving             0.601330           0.323938
# facet_self_discipline                  0.614592           0.475452
# facet_cautiousness                     0.295060           0.319483
# facet_friendliness                     0.281169           0.117180
# facet_gregariousness                   0.156856           0.042098
# facet_assertiveness                    0.474024           0.140547
# facet_activity_level                   0.377581           0.213292
# facet_excitement_seeking               0.001283          -0.173563
# facet_cheerfulness                     0.337895           0.117532
# facet_trust                            0.147421           0.027014
# facet_morality                         0.208688           0.182194
# facet_altruism                         0.201396           0.079628
# facet_cooperation                      0.127637           0.176857
# facet_modesty                         -0.248925          -0.001299
# facet_sympathy                         0.060104           0.008259
# facet_anxiety                         -0.282430          -0.098177
# facet_anger                           -0.151852          -0.124325
# facet_depression                      -0.392907          -0.212924
# facet_self_consciousness              -0.257868          -0.085936
# facet_immoderation                    -0.246587          -0.251399
# facet_vulnerability                   -0.409006          -0.142034
#
#                             facet_dutifulness  facet_achievement_striving  \
# facet_imagination                   -0.207237                   -0.146134
# facet_artistic_interests             0.015612                    0.072200
# facet_emotionality                   0.081860                    0.076506
# facet_adventurousness               -0.064307                    0.087044
# facet_intellect                      0.020532                    0.117019
# facet_liberalism                    -0.188993                   -0.131252
# facet_self_efficacy                  0.373003                    0.601330
# facet_orderliness                    0.311126                    0.323938
# facet_dutifulness                    1.000000                    0.406161
# facet_achievement_striving           0.406161                    1.000000
# facet_self_discipline                0.429801                    0.598557
# facet_cautiousness                   0.429987                    0.305377
# facet_friendliness                   0.148730                    0.210759
# facet_gregariousness                -0.009428                    0.088423
# facet_assertiveness                  0.103940                    0.358555
# facet_activity_level                 0.193638                    0.458911
# facet_excitement_seeking            -0.297583                   -0.098652
# facet_cheerfulness                   0.186397                    0.234543
# facet_trust                          0.206677                    0.114459
# facet_morality                       0.497797                    0.322228
# facet_altruism                       0.317615                    0.262401
# facet_cooperation                    0.380597                    0.213747
# facet_modesty                        0.080422                   -0.053527
# facet_sympathy                       0.157788                    0.134402
# facet_anxiety                       -0.151165                   -0.160148
# facet_anger                         -0.253872                   -0.143138
# facet_depression                    -0.252274                   -0.274219
# facet_self_consciousness            -0.035804                   -0.170430
# facet_immoderation                  -0.356695                   -0.239849
# facet_vulnerability                 -0.207102                   -0.251242
#
#                             facet_self_discipline  facet_cautiousness  \
# facet_imagination                       -0.245610           -0.251124
# facet_artistic_interests                 0.004675            0.034904
# facet_emotionality                       0.004545           -0.023483
# facet_adventurousness                    0.075984           -0.060523
# facet_intellect                          0.034156            0.110769
# facet_liberalism                        -0.153561           -0.078810
# facet_self_efficacy                      0.614592            0.295060
# facet_orderliness                        0.475452            0.319483
# facet_dutifulness                        0.429801            0.429987
# facet_achievement_striving               0.598557            0.305377
# facet_self_discipline                    1.000000            0.371207
# facet_cautiousness                       0.371207            1.000000
# facet_friendliness                       0.308514            0.011169
# facet_gregariousness                     0.178163           -0.133824
# facet_assertiveness                      0.387317            0.048052
# facet_activity_level                     0.475928            0.086113
# facet_excitement_seeking                -0.089801           -0.452385
# facet_cheerfulness                       0.330598            0.018086
# facet_trust                              0.127616            0.043751
# facet_morality                           0.249964            0.326193
# facet_altruism                           0.171421            0.117997
# facet_cooperation                        0.186925            0.358392
# facet_modesty                           -0.125259            0.020919
# facet_sympathy                           0.060409            0.057880
# facet_anxiety                           -0.283926           -0.196581
# facet_anger                             -0.196662           -0.299097
# facet_depression                        -0.427343           -0.210042
# facet_self_consciousness                -0.270424            0.013474
# facet_immoderation                      -0.349250           -0.392257
# facet_vulnerability                     -0.374658           -0.251257
#
#                             facet_friendliness  facet_gregariousness  \
# facet_imagination                    -0.085551             -0.043568
# facet_artistic_interests              0.040260              0.026728
# facet_emotionality                    0.126293              0.073769
# facet_adventurousness                 0.267482              0.295630
# facet_intellect                      -0.004317             -0.034448
# facet_liberalism                     -0.061580             -0.012370
# facet_self_efficacy                   0.281169              0.156856
# facet_orderliness                     0.117180              0.042098
# facet_dutifulness                     0.148730             -0.009428
# facet_achievement_striving            0.210759              0.088423
# facet_self_discipline                 0.308514              0.178163
# facet_cautiousness                    0.011169             -0.133824
# facet_friendliness                    1.000000              0.710872
# facet_gregariousness                  0.710872              1.000000
# facet_assertiveness                   0.375318              0.322921
# facet_activity_level                  0.285095              0.256224
# facet_excitement_seeking              0.267038              0.420883
# facet_cheerfulness                    0.608707              0.486362
# facet_trust                           0.395177              0.246391
# facet_morality                        0.126660             -0.026536
# facet_altruism                        0.334166              0.196786
# facet_cooperation                     0.106488             -0.053939
# facet_modesty                        -0.140608             -0.146072
# facet_sympathy                        0.172766              0.098093
# facet_anxiety                        -0.359537             -0.257772
# facet_anger                          -0.223006             -0.105514
# facet_depression                     -0.512232             -0.353958
# facet_self_consciousness             -0.678021             -0.617648
# facet_immoderation                   -0.083374              0.050608
# facet_vulnerability                  -0.355467             -0.245278
#
#                             facet_assertiveness  facet_activity_level  \
# facet_imagination                     -0.037680             -0.120114
# facet_artistic_interests               0.062403              0.029652
# facet_emotionality                     0.062401              0.030101
# facet_adventurousness                  0.216017              0.137293
# facet_intellect                        0.156144              0.031286
# facet_liberalism                      -0.074365             -0.093247
# facet_self_efficacy                    0.474024              0.377581
# facet_orderliness                      0.140547              0.213292
# facet_dutifulness                      0.103940              0.193638
# facet_achievement_striving             0.358555              0.458911
# facet_self_discipline                  0.387317              0.475928
# facet_cautiousness                     0.048052              0.086113
# facet_friendliness                     0.375318              0.285095
# facet_gregariousness                   0.322921              0.256224
# facet_assertiveness                    1.000000              0.374951
# facet_activity_level                   0.374951              1.000000
# facet_excitement_seeking               0.200155              0.106124
# facet_cheerfulness                     0.307722              0.279466
# facet_trust                            0.041232              0.099107
# facet_morality                        -0.019769              0.085299
# facet_altruism                         0.128022              0.147206
# facet_cooperation                     -0.132128              0.039286
# facet_modesty                         -0.333269             -0.122431
# facet_sympathy                         0.036620              0.072086
# facet_anxiety                         -0.239818             -0.116646
# facet_anger                            0.031556             -0.060239
# facet_depression                      -0.310259             -0.249173
# facet_self_consciousness              -0.452301             -0.256092
# facet_immoderation                    -0.068269             -0.140742
# facet_vulnerability                   -0.328465             -0.165601
#
#                             facet_excitement_seeking  facet_cheerfulness  \
# facet_imagination                           0.306732            0.005324
# facet_artistic_interests                    0.101355            0.102904
# facet_emotionality                          0.054933            0.085801
# facet_adventurousness                       0.334492            0.226369
# facet_intellect                             0.046534            0.010926
# facet_liberalism                            0.080856           -0.066196
# facet_self_efficacy                         0.001283            0.337895
# facet_orderliness                          -0.173563            0.117532
# facet_dutifulness                          -0.297583            0.186397
# facet_achievement_striving                 -0.098652            0.234543
# facet_self_discipline                      -0.089801            0.330598
# facet_cautiousness                         -0.452385            0.018086
# facet_friendliness                          0.267038            0.608707
# facet_gregariousness                        0.420883            0.486362
# facet_assertiveness                         0.200155            0.307722
# facet_activity_level                        0.106124            0.279466
# facet_excitement_seeking                    1.000000            0.285073
# facet_cheerfulness                          0.285073            1.000000
# facet_trust                                 0.024353            0.400472
# facet_morality                             -0.215752            0.152384
# facet_altruism                              0.023732            0.330401
# facet_cooperation                          -0.313664            0.171747
# facet_modesty                              -0.142001           -0.221094
# facet_sympathy                              0.009225            0.187919
# facet_anxiety                              -0.123250           -0.409949
# facet_anger                                 0.099905           -0.313059
# facet_depression                           -0.065063           -0.655976
# facet_self_consciousness                   -0.295244           -0.456723
# facet_immoderation                          0.250626           -0.125470
# facet_vulnerability                        -0.083600           -0.390238
#
#                             facet_trust  facet_morality  facet_altruism  \
# facet_imagination             -0.031716       -0.096149        0.071136
# facet_artistic_interests       0.046417        0.131178        0.248464
# facet_emotionality             0.101505        0.143609        0.481985
# facet_adventurousness          0.096045        0.074561        0.125779
# facet_intellect                0.002914        0.110021        0.160199
# facet_liberalism               0.010266       -0.085458       -0.004454
# facet_self_efficacy            0.147421        0.208688        0.201396
# facet_orderliness              0.027014        0.182194        0.079628
# facet_dutifulness              0.206677        0.497797        0.317615
# facet_achievement_striving     0.114459        0.322228        0.262401
# facet_self_discipline          0.127616        0.249964        0.171421
# facet_cautiousness             0.043751        0.326193        0.117997
# facet_friendliness             0.395177        0.126660        0.334166
# facet_gregariousness           0.246391       -0.026536        0.196786
# facet_assertiveness            0.041232       -0.019769        0.128022
# facet_activity_level           0.099107        0.085299        0.147206
# facet_excitement_seeking       0.024353       -0.215752        0.023732
# facet_cheerfulness             0.400472        0.152384        0.330401
# facet_trust                    1.000000        0.209164        0.327923
# facet_morality                 0.209164        1.000000        0.390962
# facet_altruism                 0.327923        0.390962        1.000000
# facet_cooperation              0.302399        0.479392        0.305708
# facet_modesty                 -0.009557        0.275209        0.144262
# facet_sympathy                 0.227806        0.276980        0.557083
# facet_anxiety                 -0.238497       -0.176437       -0.062549
# facet_anger                   -0.310748       -0.283746       -0.222314
# facet_depression              -0.297855       -0.187478       -0.144868
# facet_self_consciousness      -0.183587       -0.016163       -0.138504
# facet_immoderation            -0.091138       -0.269408       -0.084504
# facet_vulnerability           -0.175440       -0.193989       -0.112964
#
#                             facet_cooperation  facet_modesty  facet_sympathy  \
# facet_imagination                   -0.124615      -0.039667        0.107249
# facet_artistic_interests             0.118275      -0.001313        0.277265
# facet_emotionality                   0.075309       0.058612        0.356530
# facet_adventurousness                0.053595      -0.067652        0.129477
# facet_intellect                      0.071284      -0.111258        0.192713
# facet_liberalism                     0.000349      -0.027403        0.128739
# facet_self_efficacy                  0.127637      -0.248925        0.060104
# facet_orderliness                    0.176857      -0.001299        0.008259
# facet_dutifulness                    0.380597       0.080422        0.157788
# facet_achievement_striving           0.213747      -0.053527        0.134402
# facet_self_discipline                0.186925      -0.125259        0.060409
# facet_cautiousness                   0.358392       0.020919        0.057880
# facet_friendliness                   0.106488      -0.140608        0.172766
# facet_gregariousness                -0.053939      -0.146072        0.098093
# facet_assertiveness                 -0.132128      -0.333269        0.036620
# facet_activity_level                 0.039286      -0.122431        0.072086
# facet_excitement_seeking            -0.313664      -0.142001        0.009225
# facet_cheerfulness                   0.171747      -0.221094        0.187919
# facet_trust                          0.302399      -0.009557        0.227806
# facet_morality                       0.479392       0.275209        0.276980
# facet_altruism                       0.305708       0.144262        0.557083
# facet_cooperation                    1.000000       0.201674        0.220715
# facet_modesty                        0.201674       1.000000        0.152437
# facet_sympathy                       0.220715       0.152437        1.000000
# facet_anxiety                       -0.200142       0.141717        0.002338
# facet_anger                         -0.578574      -0.052400       -0.143945
# facet_depression                    -0.198321       0.313132       -0.036488
# facet_self_consciousness             0.008535       0.240122       -0.050657
# facet_immoderation                  -0.250769      -0.015109       -0.047758
# facet_vulnerability                 -0.187012       0.161705       -0.018559
#
#                             facet_anxiety  facet_anger  facet_depression  \
# facet_imagination                0.121094     0.105669          0.192889
# facet_artistic_interests        -0.060234    -0.109452          0.026902
# facet_emotionality               0.180802     0.062218          0.114508
# facet_adventurousness           -0.359954    -0.185652         -0.189165
# facet_intellect                 -0.141704    -0.102461          0.001567
# facet_liberalism                 0.017029    -0.034210          0.095894
# facet_self_efficacy             -0.282430    -0.151852         -0.392907
# facet_orderliness               -0.098177    -0.124325         -0.212924
# facet_dutifulness               -0.151165    -0.253872         -0.252274
# facet_achievement_striving      -0.160148    -0.143138         -0.274219
# facet_self_discipline           -0.283926    -0.196662         -0.427343
# facet_cautiousness              -0.196581    -0.299097         -0.210042
# facet_friendliness              -0.359537    -0.223006         -0.512232
# facet_gregariousness            -0.257772    -0.105514         -0.353958
# facet_assertiveness             -0.239818     0.031556         -0.310259
# facet_activity_level            -0.116646    -0.060239         -0.249173
# facet_excitement_seeking        -0.123250     0.099905         -0.065063
# facet_cheerfulness              -0.409949    -0.313059         -0.655976
# facet_trust                     -0.238497    -0.310748         -0.297855
# facet_morality                  -0.176437    -0.283746         -0.187478
# facet_altruism                  -0.062549    -0.222314         -0.144868
# facet_cooperation               -0.200142    -0.578574         -0.198321
# facet_modesty                    0.141717    -0.052400          0.313132
# facet_sympathy                   0.002338    -0.143945         -0.036488
# facet_anxiety                    1.000000     0.446670          0.569887
# facet_anger                      0.446670     1.000000          0.358831
# facet_depression                 0.569887     0.358831          1.000000
# facet_self_consciousness         0.417607     0.171922          0.458328
# facet_immoderation               0.224088     0.263877          0.286231
# facet_vulnerability              0.729536     0.409510          0.548560
#
#                             facet_self_consciousness  facet_immoderation  \
# facet_imagination                           0.052260            0.204437
# facet_artistic_interests                   -0.076235           -0.002240
# facet_emotionality                         -0.037295            0.081290
# facet_adventurousness                      -0.356023           -0.000214
# facet_intellect                            -0.099355           -0.023154
# facet_liberalism                            0.017717            0.112502
# facet_self_efficacy                        -0.257868           -0.246587
# facet_orderliness                          -0.085936           -0.251399
# facet_dutifulness                          -0.035804           -0.356695
# facet_achievement_striving                 -0.170430           -0.239849
# facet_self_discipline                      -0.270424           -0.349250
# facet_cautiousness                          0.013474           -0.392257
# facet_friendliness                         -0.678021           -0.083374
# facet_gregariousness                       -0.617648            0.050608
# facet_assertiveness                        -0.452301           -0.068269
# facet_activity_level                       -0.256092           -0.140742
# facet_excitement_seeking                   -0.295244            0.250626
# facet_cheerfulness                         -0.456723           -0.125470
# facet_trust                                -0.183587           -0.091138
# facet_morality                             -0.016163           -0.269408
# facet_altruism                             -0.138504           -0.084504
# facet_cooperation                           0.008535           -0.250769
# facet_modesty                               0.240122           -0.015109
# facet_sympathy                             -0.050657           -0.047758
# facet_anxiety                               0.417607            0.224088
# facet_anger                                 0.171922            0.263877
# facet_depression                            0.458328            0.286231
# facet_self_consciousness                    1.000000            0.072402
# facet_immoderation                          0.072402            1.000000
# facet_vulnerability                         0.424166            0.260949
#
#                             facet_vulnerability
# facet_imagination                      0.107693
# facet_artistic_interests              -0.069258
# facet_emotionality                     0.141560
# facet_adventurousness                 -0.334549
# facet_intellect                       -0.181511
# facet_liberalism                       0.043565
# facet_self_efficacy                   -0.409006
# facet_orderliness                     -0.142034
# facet_dutifulness                     -0.207102
# facet_achievement_striving            -0.251242
# facet_self_discipline                 -0.374658
# facet_cautiousness                    -0.251257
# facet_friendliness                    -0.355467
# facet_gregariousness                  -0.245278
# facet_assertiveness                   -0.328465
# facet_activity_level                  -0.165601
# facet_excitement_seeking              -0.083600
# facet_cheerfulness                    -0.390238
# facet_trust                           -0.175440
# facet_morality                        -0.193989
# facet_altruism                        -0.112964
# facet_cooperation                     -0.187012
# facet_modesty                          0.161705
# facet_sympathy                        -0.018559
# facet_anxiety                          0.729536
# facet_anger                            0.409510
# facet_depression                       0.548560
# facet_self_consciousness               0.424166
# facet_immoderation                     0.260949
# facet_vulnerability                    1.000000

# %%
plt.figure(figsize=(20, 16))

cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(
    df_matrix_facets.corr(),
    annot=True,
    cmap=cmap,
    vmax=0.3,
    center=0,
    square=True,
    linewidths=0.5,
    cbar_kws={"shrink": 0.5},
    annot_kws={"size": 8},
)

plt.xticks(rotation=45, ha="right", fontsize=10)
plt.yticks(rotation=0, fontsize=10)

plt.show()

# %% [markdown]
# ## Clustering

# %%
X = df.copy()

O = X.filter(
    [
        "facet_imagination",
        "facet_artistic_interests",
        "facet_emotionality",
        "facet_adventurousness",
        "facet_intellect",
        "facet_liberalism",
    ]
)
C = X.filter(
    [
        "facet_self_efficacy",
        "facet_orderliness",
        "facet_dutifulness",
        "facet_achievement_striving",
        "facet_self_discipline",
        "facet_cautiousness",
    ]
)
E = X.filter(
    [
        "facet_friendliness",
        "facet_gregariousness",
        "facet_assertiveness",
        "facet_activity_level",
        "facet_excitement_seeking",
        "facet_cheerfulness",
    ]
)
A = X.filter(
    [
        "facet_trust",
        "facet_morality",
        "facet_altruism",
        "facet_cooperation",
        "facet_modesty",
        "facet_sympathy",
    ]
)
N = X.filter(
    [
        "facet_anxiety",
        "facet_anger",
        "facet_depression",
        "facet_self_consciousness",
        "facet_immoderation",
        "facet_vulnerability",
    ]
)

model = pd.concat([O, C, E, A, N], axis=1)
model.head()
# Out:
#    facet_imagination  facet_artistic_interests  facet_emotionality  \
# 0          75.254232                 40.432058           73.068513
# 1          64.308584                 61.025761           31.735332
# 2          53.844029                 45.316184            3.200967
# 3           8.914197                 60.988360           49.758720
# 4          53.832540                 61.025761           44.585253
#
#    facet_adventurousness  facet_intellect  facet_liberalism  \
# 0              71.832186        59.478950         36.369613
# 1              88.251745        57.360264         92.935640
# 2              90.676932        74.703513         90.450637
# 3              81.244372        86.121119         25.431828
# 4              41.349092        47.129696         69.477439
#
#    facet_self_efficacy  facet_orderliness  facet_dutifulness  \
# 0            59.751318          32.342786          54.892857
# 1            89.733171          68.013111          44.963610
# 2            93.299004          24.272619          14.383704
# 3            84.580163          65.878251          78.953690
# 4            49.695823          52.603005          44.963610
#
#    facet_achievement_striving  facet_self_discipline  facet_cautiousness  \
# 0                   63.675297              41.888264           84.032423
# 1                   16.580116              84.633574           67.456166
# 2                   80.885654              99.646135           74.813500
# 3                   82.391009              83.566408           60.403585
# 4                   16.580116              43.843893           42.280102
#
#    facet_friendliness  facet_gregariousness  facet_assertiveness  \
# 0           74.071748             65.945007            77.299926
# 1           77.267973             94.271135            47.536294
# 2           70.526550             86.659049            39.758576
# 3           74.071748             81.190659            96.180870
# 4           49.513820             59.439053            37.789326
#
#    facet_activity_level  facet_excitement_seeking  facet_cheerfulness  \
# 0             12.265075                 23.740125           66.964675
# 1             96.065024                 87.511279            5.776425
# 2             92.707965                 73.646661           65.158443
# 3             97.498896                 23.740125           56.848582
# 4             41.578470                 22.776857           88.517103
#
#    facet_trust  facet_morality  facet_altruism  facet_cooperation  \
# 0    73.438475       72.159605       67.393775          76.776519
# 1    13.978142       83.405900       89.448233           4.270395
# 2     7.526992        7.408120        2.417954           3.278791
# 3    27.248015       72.159605       54.492760          52.320264
# 4    83.907554       58.955730       66.457831          82.330021
#
#    facet_modesty  facet_sympathy  facet_anxiety  facet_anger  \
# 0      74.954334       77.384533      27.993157    11.549711
# 1      69.646885       67.981348      58.854938    89.843818
# 2      24.018170       12.400848      33.979027    86.802916
# 3      38.542547       41.268613      12.195029    57.719898
# 4      50.199377       55.939489      21.800273     7.899414
#
#    facet_depression  facet_self_consciousness  facet_immoderation  \
# 0         58.018551                 39.725121           96.864432
# 1         89.880570                 57.486716            1.000000
# 2         29.000871                  7.509259            6.890607
# 3         18.108659                  8.870845           44.831762
# 4         26.475441                 38.817649           62.697315
#
#    facet_vulnerability
# 0            11.048211
# 1            80.327511
# 2            15.131043
# 3             5.285188
# 4            53.029251

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
kfit = kmeans.fit(model)

predictions = kfit.labels_
model["clusters"] = predictions
model.head()
# Out:
#    facet_imagination  facet_artistic_interests  facet_emotionality  \
# 0          75.254232                 40.432058           73.068513
# 1          64.308584                 61.025761           31.735332
# 2          53.844029                 45.316184            3.200967
# 3           8.914197                 60.988360           49.758720
# 4          53.832540                 61.025761           44.585253
#
#    facet_adventurousness  facet_intellect  facet_liberalism  \
# 0              71.832186        59.478950         36.369613
# 1              88.251745        57.360264         92.935640
# 2              90.676932        74.703513         90.450637
# 3              81.244372        86.121119         25.431828
# 4              41.349092        47.129696         69.477439
#
#    facet_self_efficacy  facet_orderliness  facet_dutifulness  \
# 0            59.751318          32.342786          54.892857
# 1            89.733171          68.013111          44.963610
# 2            93.299004          24.272619          14.383704
# 3            84.580163          65.878251          78.953690
# 4            49.695823          52.603005          44.963610
#
#    facet_achievement_striving  facet_self_discipline  facet_cautiousness  \
# 0                   63.675297              41.888264           84.032423
# 1                   16.580116              84.633574           67.456166
# 2                   80.885654              99.646135           74.813500
# 3                   82.391009              83.566408           60.403585
# 4                   16.580116              43.843893           42.280102
#
#    facet_friendliness  facet_gregariousness  facet_assertiveness  \
# 0           74.071748             65.945007            77.299926
# 1           77.267973             94.271135            47.536294
# 2           70.526550             86.659049            39.758576
# 3           74.071748             81.190659            96.180870
# 4           49.513820             59.439053            37.789326
#
#    facet_activity_level  facet_excitement_seeking  facet_cheerfulness  \
# 0             12.265075                 23.740125           66.964675
# 1             96.065024                 87.511279            5.776425
# 2             92.707965                 73.646661           65.158443
# 3             97.498896                 23.740125           56.848582
# 4             41.578470                 22.776857           88.517103
#
#    facet_trust  facet_morality  facet_altruism  facet_cooperation  \
# 0    73.438475       72.159605       67.393775          76.776519
# 1    13.978142       83.405900       89.448233           4.270395
# 2     7.526992        7.408120        2.417954           3.278791
# 3    27.248015       72.159605       54.492760          52.320264
# 4    83.907554       58.955730       66.457831          82.330021
#
#    facet_modesty  facet_sympathy  facet_anxiety  facet_anger  \
# 0      74.954334       77.384533      27.993157    11.549711
# 1      69.646885       67.981348      58.854938    89.843818
# 2      24.018170       12.400848      33.979027    86.802916
# 3      38.542547       41.268613      12.195029    57.719898
# 4      50.199377       55.939489      21.800273     7.899414
#
#    facet_depression  facet_self_consciousness  facet_immoderation  \
# 0         58.018551                 39.725121           96.864432
# 1         89.880570                 57.486716            1.000000
# 2         29.000871                  7.509259            6.890607
# 3         18.108659                  8.870845           44.831762
# 4         26.475441                 38.817649           62.697315
#
#    facet_vulnerability  clusters
# 0            11.048211         0
# 1            80.327511         0
# 2            15.131043         1
# 3             5.285188         4
# 4            53.029251         0

# %%
pca = PCA(n_components=2)

df_pca = pd.DataFrame(data=pca.fit_transform(model), columns=["X", "Y"])
df_pca["clusters"] = predictions

df_pca.head()
# Out:
#             X          Y  clusters
# 0  -36.125744  10.161077         0
# 1    8.020519  27.449067         0
# 2  -33.552081  75.644239         1
# 3 -102.063840   9.099313         4
# 4  -15.067314   9.913194         0

# %%
print("0: O")
print("1: C")
print("2: E")
print("3: A")
print("4: N")

plt.figure(figsize=(10, 10))
sns.scatterplot(
    data=df_pca, x="X", y="Y", hue="clusters", legend="full", palette="tab10", alpha=0.8
)
plt.title("Cluster Big-Five Facets | Visualized on PCA")
# Out:
# 0: O
# 1: C
# 2: E
# 3: A
# 4: N
# Text(0.5, 1.0, 'Cluster Big-Five Facets | Visualized on PCA')

# %%
########################上面是Kaggle本身的ipip问卷调查结果展示，期末前我再删除防止我们有些可能需要调用的时候没有#####################

# %%
# 如果环境里还没有 openai
# !pip install --quiet openai

# %%
# 配置python
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from itertools import combinations
from scipy import stats
from scipy.stats import wasserstein_distance

# %%
# 我的openAI API key 配置
from kaggle_secrets import UserSecretsClient

from openai import OpenAI

user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("OPENAI_API_KEY")

client = OpenAI(api_key=secret_value_0)

# %%
# 随机种子方便复现
RANDOM_SEED = 42
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# 在 /kaggle/input 下面看到的真实data路径
DATA_PATH = "/kaggle/input/pip-neo-big-five-personality-120-item-version/IPIP120-SCORES.csv"

# 这五个列名要和CSV 对上, 我检查过了对其
DOMAINS = [
    "openness",
    "conscientiousness",
    "extraversion",
    "agreeableness",
    "neuroticism",
]

# %%
# 读上传的 dataset
def load_human_scores(path: str) -> pd.DataFrame:
    df = pd.read_csv(path)

    # 分sex → sex_label
    if "sex" in df.columns:
        sex_map = {1: "male", 2: "female"}
        if df["sex"].dtype != object:
            df["sex_label"] = df["sex"].map(sex_map).fillna(df["sex"].astype(str))
        else:
            df["sex_label"] = df["sex"]
    else:
        df["sex_label"] = "unknown"

    # 分age → age_bin
    if "age" in df.columns:
        bins = [0, 17, 25, 35, 50, 120]
        labels = ["<=17", "18-25", "26-35", "36-50", "50+"]
        df["age_bin"] = pd.cut(
            df["age"],
            bins=bins,
            labels=labels,
            right=True,
            include_lowest=True,
        )
    else:
        df["age_bin"] = "unknown"

    return df


human = load_human_scores(DATA_PATH)
human.head()
# Out:
#    case  sex  age  sec  min  hour  day  month  year    country  i1  i2  i3  \
# 0     1    2   19    8   41    16   30      6   101  South Afr   5   4   5
# 1     2    2   22   24   45    16   30      6   101        USA   5   4   4
# 2     6    1   13   14    6    17   30      6   101        USA   2   4   2
# 3     7    2   18   25   11    17   30      6   101        USA   3   4   3
# 4     8    2   24   19   25    17   30      6   101        USA   4   4   4
#
#    i4  i5  i6  i7  i8  i9  i10  i11  i12  i13  i14  i15  i16  i17  i18  i19  \
# 0   4   4   2   5   5   4    4    2    4    4    4    4    1    2    4    5
# 1   2   5   5   5   4   5    4    4    4    5    5    4    3    5    5    1
# 2   2   4   4   5   4   3    2    2    4    2    2    4    2    3    5    1
# 3   2   5   4   4   4   3    3    2    5    4    4    5    1    5    5    2
# 4   5   4   2   3   4   4    4    3    3    5    5    4    3    3    4    5
#
#    i20  i21  i22  i23  i24  i25  i26  i27  i28  i29  i30  i31  i32  i33  i34  \
# 0    4    5    4    4    3    2    2    4    2    4    4    2    4    4    4
# 1    4    1    5    3    4    4    3    2    5    4    3    4    4    5    2
# 2    4    1    5    5    2    4    1    3    3    2    4    2    4    5    2
# 3    4    4    4    5    3    3    1    3    2    3    2    2    4    2    3
# 4    4    3    3    4    5    3    3    5    4    4    3    2    4    3    4
#
#    i35  i36  i37  i38  i39  i40  ...  i108  i109  i110  i111  i112  i113  \
# 0    4    2    4    4    4    1  ...     3     4     4     5     2     4
# 1    4    5    4    4    5    5  ...     4     2     5     1     4     3
# 2    5    5    4    2    3    2  ...     5     1     5     1     2     4
# 3    5    4    5    4    5    4  ...     3     4     5     2     3     4
# 4    4    1    4    4    5    3  ...     2     4     2     3     2     4
#
#    i114  i115  i116  i117  i118  i119  i120   openness  facet_imagination  \
# 0     4     4     2     4     1     5     4  64.796448          75.254232
# 1     3     4     4     2     3     4     3  79.613711          64.308584
# 2     3     5     2     4     4     3     5  64.261833          53.844029
# 3     4     5     2     4     2     4     3  55.968730           8.914197
# 4     4     3     1     5     3     4     4  55.117886          53.832540
#
#    facet_artistic_interests  facet_emotionality  facet_adventurousness  \
# 0                 40.432058           73.068513              71.832186
# 1                 61.025761           31.735332              88.251745
# 2                 45.316184            3.200967              90.676932
# 3                 60.988360           49.758720              81.244372
# 4                 61.025761           44.585253              41.349092
#
#    facet_intellect  facet_liberalism  conscientiousness  facet_self_efficacy  \
# 0        59.478950         36.369613          59.184103            59.751318
# 1        57.360264         92.935640          68.648552            89.733171
# 2        74.703513         90.450637          74.412693            93.299004
# 3        86.121119         25.431828          83.546408            84.580163
# 4        47.129696         69.477439          38.370685            49.695823
#
#    facet_orderliness  facet_dutifulness  facet_achievement_striving  \
# 0          32.342786          54.892857                   63.675297
# 1          68.013111          44.963610                   16.580116
# 2          24.272619          14.383704                   80.885654
# 3          65.878251          78.953690                   82.391009
# 4          52.603005          44.963610                   16.580116
#
#    facet_self_discipline  facet_cautiousness  extraversion  \
# 0              41.888264           84.032423     56.493023
# 1              84.633574           67.456166     80.144284
# 2              99.646135           74.813500     80.931850
# 3              83.566408           60.403585     84.255079
# 4              43.843893           42.280102     50.534797
#
#    facet_friendliness  facet_gregariousness  facet_assertiveness  \
# 0           74.071748             65.945007            77.299926
# 1           77.267973             94.271135            47.536294
# 2           70.526550             86.659049            39.758576
# 3           74.071748             81.190659            96.180870
# 4           49.513820             59.439053            37.789326
#
#    facet_activity_level  facet_excitement_seeking  facet_cheerfulness  \
# 0             12.265075                 23.740125           66.964675
# 1             96.065024                 87.511279            5.776425
# 2             92.707965                 73.646661           65.158443
# 3             97.498896                 23.740125           56.848582
# 4             41.578470                 22.776857           88.517103
#
#    agreeableness  facet_trust  facet_morality  facet_altruism  \
# 0      84.214345    73.438475       72.159605       67.393775
# 1      47.158018    13.978142       83.405900       89.448233
# 2       1.000000     7.526992        7.408120        2.417954
# 3      44.246158    27.248015       72.159605       54.492760
# 4      77.026790    83.907554       58.955730       66.457831
#
#    facet_cooperation  facet_modesty  facet_sympathy  neuroticism  \
# 0          76.776519      74.954334       77.384533    35.573367
# 1           4.270395      69.646885       67.981348    66.998550
# 2           3.278791      24.018170       12.400848    22.577376
# 3          52.320264      38.542547       41.268613    12.466800
# 4          82.330021      50.199377       55.939489    26.353107
#
#    facet_anxiety  facet_anger  facet_depression  facet_self_consciousness  \
# 0      27.993157    11.549711         58.018551                 39.725121
# 1      58.854938    89.843818         89.880570                 57.486716
# 2      33.979027    86.802916         29.000871                  7.509259
# 3      12.195029    57.719898         18.108659                  8.870845
# 4      21.800273     7.899414         26.475441                 38.817649
#
#    facet_immoderation  facet_vulnerability  sex_label  age_bin
# 0           96.864432            11.048211     female    18-25
# 1            1.000000            80.327511     female    18-25
# 2            6.890607            15.131043       male     <=17
# 3           44.831762             5.285188     female    18-25
# 4           62.697315            53.029251     female    18-25
#
# [5 rows x 167 columns]

# %%
# 人类基准线
def describe_group(df: pd.DataFrame, group_cols, targets=DOMAINS) -> pd.DataFrame:
    outs = []
    for t in targets:
        if t not in df.columns:
            continue
        tmp = (
            df.groupby(group_cols)[t]
            .agg(["mean", "std", "count"])
            .reset_index()
            .rename(columns={"count": "n"})
        )
        tmp["metric"] = t
        outs.append(tmp)
    if outs:
        return pd.concat(outs, ignore_index=True)
    return pd.DataFrame()


baseline_sex = describe_group(human, ["sex_label"])
baseline_age = describe_group(human, ["age_bin"])

display(baseline_sex.head())
display(baseline_age.head())
# Out:
#   sex_label       mean        std       n             metric
# 0    female  40.064585  28.026286  241930           openness
# 1      male  40.911304  28.240421  168446           openness
# 2    female  55.447934  28.759354  241930  conscientiousness
# 3      male  55.270530  28.607323  168446  conscientiousness
# 4    female  51.519078  27.720936  241930       extraversion
#   age_bin       mean        std       n    metric
# 0    <=17  37.863644  27.740394   70399  openness
# 1   18-25  38.943726  27.928452  207775  openness
# 2   26-35  43.425322  28.158871   74323  openness
# 3   36-50  43.843438  28.120005   45581  openness
# 4     50+  48.881715  28.842094   12298  openness

# %%
# persona 定义给Openai的 + 人类过滤，筛选18-25的人来对比
PERSONAS = [
    {
        "name": "US_male(18-25)",
        "prompt_snippet": "You are a 21-year-old male college student in the United States.",
        "human_filter": {"sex_label": ["male"], "age_bin": ["18-25"]},
    },
    {
        "name": "US_female(18-25)",
        "prompt_snippet": "You are a 21-year-old female college student in the United States.",
        "human_filter": {"sex_label": ["female"], "age_bin": ["18-25"]},
    },
    {
        "name": "Chinese_international_student(18-25)",
        "prompt_snippet": "You are a 21-year-old Chinese international student studying in the United States.",
        "human_filter": {"age_bin": ["18-25"]},
    },
]


def apply_filter(df: pd.DataFrame, flt: dict) -> pd.DataFrame:
    out = df.copy()
    for k, vals in flt.items():
        if k in out.columns:
            out = out[out[k].isin(vals)]
    return out

# %%
# prompt + 带 fallback 的调用函数（防止我的APIKEY过期,Fallback的输出会在开头有括号提示，只是为了运行流畅不出现卡顿）
IPIP_INSTRUCTION = (
    "You will answer a Big Five personality questionnaire (IPIP-NEO 120).\n"
    "Answer each item with an integer from 1 to 5 only:\n"
    "1 = Strongly disagree\n"
    "2 = Disagree\n"
    "3 = Neither agree nor disagree\n"
    "4 = Agree\n"
    "5 = Strongly agree\n"
    "Return ONLY the number."
)


def build_item_prompt(persona_snippet: str, item_text: str) -> str:
    return (
        persona_snippet.strip()
        + "\n\n"
        + IPIP_INSTRUCTION
        + "\nItem: "
        + item_text.strip()
        + "\nAnswer (1-5):"
    )


def parse_likert(resp: str) -> int:
    resp = resp.strip()
    for ch in resp:
        if ch.isdigit():
            v = int(ch)
            if 1 <= v <= 5:
                return v
    return 3

# 这边就是假的了 fallback生成防止我的api出问题不用在意，我的输出是正常的API调用输出
def fallback_score(persona_name: str, item_id: int) -> int:
    """
    本地生成一个确定性的 1..5，保证 notebook 能跑到底
    """
    base = abs(hash(persona_name + str(item_id)))
    return (base % 5) + 1


def call_llm_with_fallback(prompt: str, persona_name: str, item_id: int, model: str = "gpt-4o-mini") -> str:
    """
    先试 openai，失败就用 fallback
    """
    try:
        resp = client.chat.completions.create(
            model=model,
            messages=[{"role": "user", "content": prompt}],
            temperature=0,
            max_tokens=16,
        )
        return resp.choices[0].message.content.strip()
    except Exception as e:
        # 打个简单的标记，方便在 Kaggle 的输出里看到是 fallback 触发
        print(f"[fallback] {persona_name} item {item_id} -> {e}")
        return str(fallback_score(persona_name, item_id))

# %%
# ipip120的题目构造同时分 5 段防止API usage alert
item_ids = list(range(1, 121))
items_df = pd.DataFrame(
    {
        "item_id": item_ids,
        "item_text": [f"Item {i}" for i in item_ids],
    }
)

def item_to_domain(item_id: int) -> str:
    idx = (item_id - 1) // 24  # 0..4
    return DOMAINS[idx]

items_df["domain"] = items_df["item_id"].apply(item_to_domain)
items_df["reversed"] = 0

# %%
# OpenAI gpt4omini模型 跑问卷，gpt5太贵了 
def run_llm_survey_batched(
    persona: dict,
    items: pd.DataFrame,
    model: str = "gpt-4o-mini",
    max_items: int | None = None,
    batch_size: int = 5,
) -> pd.DataFrame:
    """
    一次问好几道题，减少 API 次数。
    要求模型按行输出 1~5，比如：
    1
    3
    4
    2
    5
    """
    rows = []
    sub = items.sort_values("item_id")
    if max_items is not None:
        sub = sub.head(max_items)

    # 分块
    for start in range(0, len(sub), batch_size):
        chunk = sub.iloc[start:start + batch_size]

        # 把这一小批题合成一个 prompt
        q_lines = []
        for i, (_, it) in enumerate(chunk.iterrows(), start=1):
            q_lines.append(f"{i}. {it['item_text']}")
        questions_block = "\n".join(q_lines)

        prompt = (
            persona["prompt_snippet"].strip()
            + "\n\n"
            + "You will answer several IPIP-NEO style items.\n"
            + "Answer EACH item with ONLY an integer from 1 to 5, one per line, in order.\n"
            + "1 = Strongly disagree\n"
            + "2 = Disagree\n"
            + "3 = Neither agree nor disagree\n"
            + "4 = Agree\n"
            + "5 = Strongly agree\n\n"
            + "Items:\n"
            + questions_block
            + "\n\nYour answers (one number per line):"
        )

        try:
            resp = client.chat.completions.create(
                model=model,
                messages=[{"role": "user", "content": prompt}],
                temperature=0,
                max_tokens=32,
            )
            text = resp.choices[0].message.content.strip()
        except Exception as e:
            # 打不过就全 fallback
            print(f"[fallback batch] {persona['name']} {chunk['item_id'].tolist()} -> {e}")
            text = "\n".join(
                str((abs(hash(persona["name"] + str(int(it["item_id"])))) % 5) + 1)
                for _, it in chunk.iterrows()
            )

        # 把模型的多行答案拆开
        answers = [line.strip() for line in text.splitlines() if line.strip()]
        # 不够的补 3（用不到，答案全是正常输出，主要防止离谱的fallback输出）
        while len(answers) < len(chunk):
            answers.append("3")

        # 逐题写回去
        for ans, (_, it) in zip(answers, chunk.iterrows()):
            score = parse_likert(ans)
            if int(it["reversed"]) == 1:
                score = 6 - score
            rows.append(
                {
                    "persona": persona["name"],
                    "item_id": int(it["item_id"]),
                    "domain": it["domain"],
                    "score": int(score),
                    "raw_response": ans,
                }
            )

    return pd.DataFrame(rows)

# %%
# 所有 persona 一起跑
all_item_answers = []
for p in PERSONAS:
    df_p = run_llm_survey_batched(
        persona=p,
        items=items_df,
        model="gpt-4o-mini",
        max_items=120,   # 总共跑 120次问答测试
        batch_size=5,# 每次请求 5 题， 120 题只要 24 次 5题是gpt4omini的单次问询上线
    )
    all_item_answers.append(df_p)

df_llm_items = pd.concat(all_item_answers, ignore_index=True)
df_llm_items.head()
# Out:
#           persona  item_id    domain  score raw_response
# 0  US_male(18-25)        1  openness      3            3
# 1  US_male(18-25)        2  openness      4            4
# 2  US_male(18-25)        3  openness      2            2
# 3  US_male(18-25)        4  openness      5            5
# 4  US_male(18-25)        5  openness      1            1

# %%
# 按 persona + domain 聚合
df_llm_domains = (
    df_llm_items
    .groupby(["persona", "domain"])["score"]
    .mean()
    .reset_index()
    .pivot(index="persona", columns="domain", values="score")
    .reset_index()
)
df_llm_domains
# Out:
# domain                               persona  agreeableness  \
# 0       Chinese_international_student(18-25)       3.333333
# 1                           US_female(18-25)       3.041667
# 2                             US_male(18-25)       2.958333
#
# domain  conscientiousness  extraversion  neuroticism  openness
# 0                3.500000      3.500000     3.416667  3.458333
# 1                3.083333      3.125000     3.125000  3.291667
# 2                3.083333      3.041667     3.000000  3.166667

# %%
# 和 Kaggle 的人类数据对比
def compare_llm_to_human(
    human_df: pd.DataFrame,
    llm_domains_df: pd.DataFrame,
    persona_dict: dict,
) -> pd.DataFrame:
    persona_name = persona_dict["name"]
    hdf = apply_filter(human_df, persona_dict.get("human_filter", {}))
    llm_row = llm_domains_df[llm_domains_df["persona"] == persona_name]

    results = []
    for d in DOMAINS:
        if d not in human_df.columns:
            continue

        human_vals = hdf[d].dropna().astype(float).values
        if human_vals.size == 0:
            results.append(
                {
                    "persona": persona_name,
                    "domain": d,
                    "llm_mean": np.nan,
                    "human_mean": np.nan,
                    "mean_diff": np.nan,
                    "cohens_d": np.nan,
                    "w1": np.nan,
                    "human_n": 0,
                }
            )
            continue

        human_mean = human_vals.mean()
        human_std = human_vals.std(ddof=1)

        if llm_row.shape[0] == 0 or d not in llm_row.columns:
            llm_mean = np.nan
        else:
            llm_mean = float(llm_row.iloc[0][d])

        mean_diff = llm_mean - human_mean
        if human_std > 0:
            d_cohen = mean_diff / human_std
        else:
            d_cohen = np.nan

        w1 = wasserstein_distance([llm_mean], human_vals)

        results.append(
            {
                "persona": persona_name,
                "domain": d,
                "llm_mean": llm_mean,
                "human_mean": human_mean,
                "mean_diff": mean_diff,
                "cohens_d": d_cohen,
                "w1": w1,
                "human_n": human_vals.size,
            }
        )
    return pd.DataFrame(results)


all_cmp = []
for p in PERSONAS:
    all_cmp.append(compare_llm_to_human(human, df_llm_domains, p))

df_cmp = pd.concat(all_cmp, ignore_index=True)
df_cmp
# Out:
#                                  persona             domain  llm_mean  \
# 0                         US_male(18-25)           openness  3.166667
# 1                         US_male(18-25)  conscientiousness  3.083333
# 2                         US_male(18-25)       extraversion  3.041667
# 3                         US_male(18-25)      agreeableness  2.958333
# 4                         US_male(18-25)        neuroticism  3.000000
# 5                       US_female(18-25)           openness  3.291667
# 6                       US_female(18-25)  conscientiousness  3.083333
# 7                       US_female(18-25)       extraversion  3.125000
# 8                       US_female(18-25)      agreeableness  3.041667
# 9                       US_female(18-25)        neuroticism  3.125000
# 10  Chinese_international_student(18-25)           openness  3.458333
# 11  Chinese_international_student(18-25)  conscientiousness  3.500000
# 12  Chinese_international_student(18-25)       extraversion  3.500000
# 13  Chinese_international_student(18-25)      agreeableness  3.333333
# 14  Chinese_international_student(18-25)        neuroticism  3.416667
#
#     human_mean  mean_diff  cohens_d         w1  human_n
# 0    39.709155 -36.542488 -1.301423  36.915614    86308
# 1    55.888351 -52.805018 -1.862020  52.928416    86308
# 2    55.988250 -52.946583 -1.910994  53.086930    86308
# 3    52.887455 -49.929122 -1.878622  50.061052    86308
# 4    42.838866 -39.838866 -1.446752  39.996435    86308
# 5    38.399853 -35.108187 -1.262503  35.530071   121467
# 6    56.706717 -53.623384 -1.874809  53.754541   121467
# 7    51.507717 -48.382717 -1.782288  48.552120   121467
# 8    51.545020 -48.503354 -1.814299  48.666986   121467
# 9    45.802602 -42.677602 -1.522879  42.849540   121467
# 10   38.943726 -35.485393 -1.270582  35.933909   207775
# 11   56.366775 -52.866775 -1.854706  53.025653   207775
# 12   53.368893 -49.868893 -1.815448  50.063032   207775
# 13   52.102656 -48.769323 -1.828126  48.948166   207775
# 14   44.571491 -41.154824 -1.477146  41.356130   207775

# %%
# 因为原本数据集 human 那个五大人格是 0~120 这种大分值
human_scaled = human.copy()
for col in DOMAINS:
    if col in human_scaled.columns:
        max_val = human_scaled[col].max()
        # 防止除以0
        if max_val > 0:
            # 把人类的这个人格分数压到 1~5
            human_scaled[col] = 1 + 4 * (human_scaled[col] / max_val)

# 然后用 human_scaled 再跑一遍对比
all_cmp_scaled = []
for p in PERSONAS:
    cmp_df = compare_llm_to_human(human_scaled, df_llm_domains, p)
    all_cmp_scaled.append(cmp_df)

df_cmp_scaled = pd.concat(all_cmp_scaled, ignore_index=True)
df_cmp_scaled
# Out:
#                                  persona             domain  llm_mean  \
# 0                         US_male(18-25)           openness  3.166667
# 1                         US_male(18-25)  conscientiousness  3.083333
# 2                         US_male(18-25)       extraversion  3.041667
# 3                         US_male(18-25)      agreeableness  2.958333
# 4                         US_male(18-25)        neuroticism  3.000000
# 5                       US_female(18-25)           openness  3.291667
# 6                       US_female(18-25)  conscientiousness  3.083333
# 7                       US_female(18-25)       extraversion  3.125000
# 8                       US_female(18-25)      agreeableness  3.041667
# 9                       US_female(18-25)        neuroticism  3.125000
# 10  Chinese_international_student(18-25)           openness  3.458333
# 11  Chinese_international_student(18-25)  conscientiousness  3.500000
# 12  Chinese_international_student(18-25)       extraversion  3.500000
# 13  Chinese_international_student(18-25)      agreeableness  3.333333
# 14  Chinese_international_student(18-25)        neuroticism  3.416667
#
#     human_mean  mean_diff  cohens_d        w1  human_n
# 0     2.593548   0.573119  0.508617  1.086496    86308
# 1     3.242827  -0.159494 -0.140145  0.982874    86308
# 2     3.246837  -0.205170 -0.184527  0.967838    86308
# 3     3.122406  -0.164072 -0.153831  0.912108    86308
# 4     2.719145   0.280855  0.254153  0.977758    86308
# 5     2.541005   0.750662  0.672657  1.156198   121467
# 6     3.275668  -0.192335 -0.167566  0.999432   121467
# 7     3.067031   0.057969  0.053212  0.919661   121467
# 8     3.068533  -0.026866 -0.025042  0.906355   121467
# 9     2.838081   0.286919  0.255123  0.993787   121467
# 10    2.562831   0.895502  0.798998  1.226900   207775
# 11    3.262026   0.237974  0.208040  0.975511   207775
# 12    3.141721   0.358279  0.325013  0.948034   207775
# 13    3.090911   0.242422  0.226442  0.907202   207775
# 14    2.788676   0.627991  0.561670  1.093631   207775

# %%
for persona in df_cmp_scaled["persona"].unique():
    tmp = df_cmp_scaled[df_cmp_scaled["persona"] == persona].set_index("domain").loc[DOMAINS]
    tmp["mean_diff"].plot(kind="bar", figsize=(6,3))
    plt.axhline(0, linestyle="--", color="gray")
    plt.title(f"{persona} – LLM vs Human (scaled to 1–5)")
    plt.ylabel("LLM_mean - Human_mean (scaled)")
    plt.tight_layout()
    plt.show()

# %%
三个 persona 都比各自的人类基线更“开放”（openness）
图里 openness 的柱子都是正的，而且幅度最大，说明只要你给 LLM 一个角色，它在 “我喜欢尝试新事物 / 我有想象力” 这类题上，会比同年龄/性别/地区的人类样本更肯给高分。换句话说，LLM 的人格回答天生偏高开放度。

美籍男生/女生 persona 在“责任心”（conscientiousness）上反而略低或者接近人类
US_male 和 US_female 的 conscientiousness 都是小幅负值或接近 0，说明 LLM 扮演美国 21 岁成人的时候，对“有条理、做事计划性强”这类题不会特别夸张，甚至比真实样本略保守一点。这个可以解读成：它在这个维度上没有瞎吹自己，跟人很像。

外向（extraversion）、宜人（agreeableness）、情绪性/神经质（neuroticism）整体是“稍微比人高一点点”
US 的两个 persona 都是小正值，说明 LLM 会把自己说得 稍微更外向一点、更好相处一点、情绪上也稍微更有起伏一点，但都不是离谱的大差距，是“看得见但不夸张”的水平。

“Chinese_international_student” 这个 persona 的整体分数都比对应人类高
你图里的第三个明显所有柱子都往上，尤其 neuroticism（神经质）升得最多。这个很有意思，说明光改角色提示，就能让同一个模型在所有大五维度上整体往上推一截，而且对“留学生”这个角色它会给得更高一点，表现出一种“更敏感/更多情绪起伏/也更友好更外向”的画像。这个就是你想要的：persona prompt 会系统性地改变量表得分 → 说明存在 prompt-induced bias。
因此
我们用同一份 IPIP 题，让 LLM 扮演不同群体；再和真实的群体（从 Kaggle 的 IPIP120-SCORES 里按性别/年龄切出来的）做对比；

发现 LLM 的回答不是固定的，而是会随 persona 系统性地高/低某些人格维度；

尤其是 openness 和（在特定 persona 下的）neuroticism，偏移最明显，这是典型的 LLM bias 表现。

在同一份人格量表上，LLM 会因为角色提示而整体高估自己的开放性，并且在“留学生”这一 persona 下对所有人格维度都给出高于真实人类样本的评分，这说明 LLM 的人格自身对 prompt 很敏感，存在 persona-induced bias。

# %%
# 如果环境里还没有 Gemini SDK（google-genai）
# !pip install -q google-genai

# %%
from kaggle_secrets import UserSecretsClient
from google import genai   # ✅ 注意是 google.genai，不是 openai

user_secrets = UserSecretsClient()
GEMINI_API_KEY = user_secrets.get_secret("GEMINI_API_KEY")  # Kaggle 右边 Secrets 里的名字要一致

# 这个 client 就是后面 call_llm_with_fallback 在用的 client
client = genai.Client(api_key=GEMINI_API_KEY)

# %%
# prompt + 带 fallback 的调用函数（Gemini 版本）
IPIP_INSTRUCTION = (
    "You will answer a Big Five personality questionnaire (IPIP-NEO 120).\n"
    "Answer each item with an integer from 1 to 5 only:\n"
    "1 = Strongly disagree\n"
    "2 = Disagree\n"
    "3 = Neither agree nor disagree\n"
    "4 = Agree\n"
    "5 = Strongly agree\n"
    "Return ONLY the number."
)

def build_item_prompt(persona_snippet: str, item_text: str) -> str:
    """
    把 persona 描述 + 问卷说明 + 具体题目 拼到一起，给 LLM 当 prompt。
    """
    return (
        persona_snippet.strip()
        + "\n\n"
        + IPIP_INSTRUCTION
        + "\nItem: "
        + item_text.strip()
        + "\nAnswer (1-5):"
    )

def parse_likert(resp: str) -> int:
    """
    从 LLM 的回复里找第一个 1~5 的数字。
    如果找不到就默认 3（中立）。
    """
    resp = resp.strip()
    for ch in resp:
        if ch.isdigit():
            v = int(ch)
            if 1 <= v <= 5:
                return v
    return 3

def fallback_score(persona_name: str, item_id: int) -> int:
    """
    简单 fallback：真的调用失败时，就给一个固定的 3 分（中立）。
    如果你想更复杂一点，也可以改成按 persona 随机 2~4 之间。
    """
    return 3

def call_llm_with_fallback(
    prompt: str,
    *,
    persona_name: str,
    item_id: int,
    model: str = "gemini-2.5-flash",
) -> str:
    """
    先用 Gemini 调一次，如果报错就用 fallback_score。
    """
    try:
        # Gemini 官方推荐的调用方式：client.models.generate_content(...)
        # 只用单轮文本输入就够了
        resp = client.models.generate_content(
            model=model,
            contents=prompt,
        )
        # resp.text 会自动把候选里的文本拼好
        return resp.text.strip()
    except Exception as e:
        # 打个简单标记，方便你在输出里看到是 fallback 触发
        print(f"[fallback] {persona_name} item {item_id} -> {e}")
        return str(fallback_score(persona_name, item_id))

# %%
# Gemini 模型 跑问卷（一次问几道，减少 API 次数）
def run_llm_survey_batched(
    persona: dict,
    items: pd.DataFrame,
    model: str = "gemini-2.5-flash",  # 默认用一个便宜/快速的 Gemini 模型
    max_items: int | None = None,
    batch_size: int = 5,
) -> pd.DataFrame:
    """
    一次问好几道题，减少 API 次数。
    要求模型按行输出 1~5，比如：
    1
    3
    4
    2
    5
    """
    rows = []

    sub = items.sort_values("item_id").reset_index(drop=True)
    if max_items is not None:
        sub = sub.head(max_items)

    # 按 batch 切分
    for start in range(0, len(sub), batch_size):
        chunk = sub.iloc[start:start + batch_size]

        # 把这一小批题合成一个 prompt
        q_lines = []
        for i, (_, it) in enumerate(chunk.iterrows(), start=1):
            q_lines.append(f"{i}. {it['item_text']}")
        questions_block = "\n".join(q_lines)

        prompt = (
            persona["prompt_snippet"].strip()
            + "\n\n"
            + IPIP_INSTRUCTION
            + "\n\n"
            + "Here are the items:\n"
            + questions_block
            + "\n\nAnswer each item with ONLY the number on its own line."
        )

        raw = call_llm_with_fallback(
            prompt,
            persona_name=persona["name"],
            # 这里随便传一个 item_id，只是为了 fallback 打 log，用当前 batch 的第一个即可
            item_id=int(chunk.iloc[0]["item_id"]),
            model=model,
        )

        # 按行拆开答案
        answers = [line.strip() for line in raw.splitlines() if line.strip()]

        # 如果返回行数和题目数对不上，做一点稳健处理
        if len(answers) != len(chunk):
            cleaned = []
            for ans in answers:
                if any(ch.isdigit() for ch in ans):
                    cleaned.append(ans)
                if len(cleaned) == len(chunk):
                    break
            # 不够就补 3
            while len(cleaned) < len(chunk):
                cleaned.append("3")
            answers = cleaned

        # 写入每一题的得分
        for (ans, (_, it)) in zip(answers, chunk.iterrows()):
            score = parse_likert(ans)
            if int(it["reversed"]) == 1:
                score = 6 - score
            rows.append(
                {
                    "persona": persona["name"],
                    "item_id": int(it["item_id"]),
                    "domain": it["domain"],
                    "score": int(score),
                    "raw_response": ans,
                }
            )

    return pd.DataFrame(rows)

# 非 batched 版本，方便你调试（和你原来的 run_llm_survey 测试那格兼容）
def run_llm_survey(
    persona: dict,
    items: pd.DataFrame,
    model: str = "gemini-2.5-flash",
    max_items: int | None = None,
) -> pd.DataFrame:
    return run_llm_survey_batched(
        persona=persona,
        items=items,
        model=model,
        max_items=max_items,
        batch_size=1,
    )

# %%
import time

def call_llm_with_fallback(
    prompt: str,
    *,
    persona_name: str,
    item_id: int,
    model: str = "gemini-2.5-flash",
    max_retries: int = 3,
) -> str:
    """
    先用 Gemini 调用；如果遇到 429（RESOURCE_EXHAUSTED），
    就等一会儿重试；超过重试次数才真正 fallback。
    """
    for attempt in range(max_retries):
        try:
            resp = client.models.generate_content(
                model=model,
                contents=prompt,
            )
            return resp.text.strip()
        except Exception as e:
            msg = str(e)
            # 专门处理 429 / 配额问题
            if "RESOURCE_EXHAUSTED" in msg or "429" in msg:
                wait = 20 * (attempt + 1)  # 第一次 20s, 第二次 40s, 第三次 60s
                print(
                    f"[rate limit] {persona_name} item {item_id} - "
                    f"attempt {attempt+1}/{max_retries}, sleep {wait}s ..."
                )
                time.sleep(wait)
                continue  # 重试
            else:
                # 其他错误，直接 fallback
                print(f"[fallback other error] {persona_name} item {item_id} -> {e}")
                return str(fallback_score(persona_name, item_id))

    # 到这里说明重试 max_retries 次都失败了，才最终 fallback
    print(f"[fallback after retries] {persona_name} item {item_id}")
    return str(fallback_score(persona_name, item_id))

# %%
def run_llm_survey_batched(
    persona: dict,
    items: pd.DataFrame,
    model: str = "gemini-2.5-flash",
    max_items: int | None = None,
    batch_size: int = 5,
) -> pd.DataFrame:
    import time

    rows = []
    sub = items.sort_values("item_id").reset_index(drop=True)
    if max_items is not None:
        sub = sub.head(max_items)

    for batch_idx, start in enumerate(range(0, len(sub), batch_size)):
        chunk = sub.iloc[start:start + batch_size]

        # 👉 每个 batch 之间休息 10 秒，降低每分钟请求数
        if batch_idx > 0:
            time.sleep(10)

        q_lines = []
        for i, (_, it) in enumerate(chunk.iterrows(), start=1):
            q_lines.append(f"{i}. {it['item_text']}")
        questions_block = "\n".join(q_lines)

        prompt = (
            persona["prompt_snippet"].strip()
            + "\n\n"
            + IPIP_INSTRUCTION
            + "\n\n"
            + "Here are the items:\n"
            + questions_block
            + "\n\n"
            + "Answer each item with ONLY the number on its own line."
        )

        raw = call_llm_with_fallback(
            prompt,
            persona_name=persona["name"],
            item_id=int(chunk.iloc[0]["item_id"]),
            model=model,
        )

        answers = [line.strip() for line in raw.splitlines() if line.strip()]
        if len(answers) != len(chunk):
            cleaned = []
            for ans in answers:
                if any(ch.isdigit() for ch in ans):
                    cleaned.append(ans)
                if len(cleaned) == len(chunk):
                    break
            while len(cleaned) < len(chunk):
                cleaned.append("3")
            answers = cleaned

        for (ans, (_, it)) in zip(answers, chunk.iterrows()):
            score = parse_likert(ans)
            if int(it["reversed"]) == 1:
                score = 6 - score
            rows.append(
                {
                    "persona": persona["name"],
                    "item_id": int(it["item_id"]),
                    "domain": it["domain"],
                    "score": int(score),
                    "raw_response": ans,
                }
            )

    return pd.DataFrame(rows)

# %%
all_item_answers = []

for p in PERSONAS:
    df_p = run_llm_survey_batched(
        persona=p,
        items=items_df,
        model="gemini-2.5-flash",
        max_items=120,  # 总共跑 120 次问答测试
        batch_size=5,
    )
    all_item_answers.append(df_p)

df_llm_items = pd.concat(all_item_answers, ignore_index=True)
df_llm_items.head()
# Out:
#           persona  item_id    domain  score raw_response
# 0  US_male(18-25)        1  openness      4            4
# 1  US_male(18-25)        2  openness      2            2
# 2  US_male(18-25)        3  openness      4            4
# 3  US_male(18-25)        4  openness      4            4
# 4  US_male(18-25)        5  openness      2            2

# %%
# human 是 Kaggle 的原始 IPIP120 人类数据（之前就有）
human_scaled = human.copy()

for col in DOMAINS:
    if col in human_scaled.columns:
        max_val = human_scaled[col].max()
        if max_val > 0:
            # 把人类该人格维度从 0~最大值 映射到 1~5
            human_scaled[col] = 1 + 4 * (human_scaled[col] / max_val)

# %%
# 按 persona + domain 聚合 Gemini 的分数
df_llm_domains = (
    df_llm_items
    .groupby(["persona", "domain"])["score"]
    .mean()
    .reset_index()
    .pivot(index="persona", columns="domain", values="score")
    .reset_index()
)
df_llm_domains.head()
# Out:
# domain                               persona  agreeableness  \
# 0       Chinese_international_student(18-25)       3.416667
# 1                           US_female(18-25)       3.708333
# 2                             US_male(18-25)       3.416667
#
# domain  conscientiousness  extraversion  neuroticism  openness
# 0                3.333333      3.541667     3.458333  3.541667
# 1                3.625000      3.333333     3.583333  3.333333
# 2                3.500000      3.500000     3.250000  3.333333

# %%
all_cmp_scaled = []
for p in PERSONAS:
    cmp_df = compare_llm_to_human(human_scaled, df_llm_domains, p)
    all_cmp_scaled.append(cmp_df)

df_cmp_scaled = pd.concat(all_cmp_scaled, ignore_index=True)
df_cmp_scaled.head()
# Out:
#           persona             domain  llm_mean  human_mean  mean_diff  \
# 0  US_male(18-25)           openness  3.333333    2.593548   0.739785
# 1  US_male(18-25)  conscientiousness  3.500000    3.242827   0.257173
# 2  US_male(18-25)       extraversion  3.500000    3.246837   0.253163
# 3  US_male(18-25)      agreeableness  3.416667    3.122406   0.294261
# 4  US_male(18-25)        neuroticism  3.250000    2.719145   0.530855
#
#    cohens_d        w1  human_n
# 0  0.656526  1.153325    86308
# 1  0.225975  0.973980    86308
# 2  0.227692  0.935728    86308
# 3  0.275894  0.907519    86308
# 4  0.480384  1.053803    86308

# %%
for persona in df_cmp_scaled["persona"].unique():
    tmp = (
        df_cmp_scaled[df_cmp_scaled["persona"] == persona]
        .set_index("domain")
        .loc[DOMAINS]
    )

    tmp["mean_diff"].plot(kind="bar", figsize=(6, 3))
    plt.axhline(0, linestyle="--")  # 0 差异的参考线
    plt.title(f"{persona} – Gemini vs Human (scaled to 1–5)")
    plt.ylabel("Gemini_mean – Human_mean (scaled)")
    plt.xlabel("domain")
    plt.tight_layout()
    plt.show()
